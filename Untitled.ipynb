# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# The following is a description of variables in uncleaned data set
#
# first = first name of player
#
# last = last name of player
#
# team = Three letter abbreviation of team they played for in that year
#
# year = listed start of the season (1980 indicated the 1980-1981 season)
#
# games_played = number of games played in the season
#
# min = average minutes played per game in the season
#
# fgm = average field goals made per game in the season
#
# fga = average field goals attempted per game in the season
#
# fg3m = average 3 point field goals made per game in the season
#
# fg3a = average 3 point field goals attempted per game in the season
#
# ftm = average free throws made per game in the season
#
# fta = average free throws attempted per game in the season
#
# oreb = average offensive rebounds per game in the season
#
# dreb = average defensive rebounds per game in the season
#
# reb = average total rebounds per game in the season
#
# ast = average assits per game in the season
#
# stl = average steals per game in the season
#
# blk = average blocks per game in the season
#
# turnover = average turnovers per game in the season
#
# pf = average personal fouls per game in the season
#
# pts = average points per game in the season
#
# fg_pct = average field goal percentage in the season
#
# fg3_pct = average 3 point field goal percentage in the season
#
# ft_pct = average free throw percentage in the season

# %%
df = pd.read_csv('final_data.csv')
df.head()
# Out:
#     first     last team  year  games_played       min   fgm    fga  fg3m  \
# 0  Julius   Erving  PHI  1980          82.0  35:02:00  9.68  18.59  0.05
# 1   Eddie  Johnson  ATL  1980          75.0  35:55:00  7.64  15.16  0.08
# 2   Artis  Gilmore  CHI  1980          81.0  34:31:00  6.67   9.93  0.00
# 3  Reggie    Theus  CHI  1980          81.0  34:20:00  6.58  13.38  0.22
# 4   Larry     Bird  BOS  1980          82.0  39:30:00  8.77  18.33  0.24
#
#    fg3a  ...    reb   ast   stl   blk  turnover    pf    pts  fg_pct  fg3_pct  \
# 0  0.22  ...   8.01  4.44  2.62  1.73      3.40  2.84  24.56   0.521    0.220
# 1  0.32  ...   2.39  5.47  1.54  0.11      2.70  2.53  19.08   0.504    0.249
# 2  0.00  ...  10.06  2.15  0.77  2.43      3.31  3.58  17.89   0.672    0.000
# 3  1.09  ...   3.56  5.41  1.73  0.28      3.65  3.14  18.84   0.492    0.203
# 4  0.92  ...  10.91  5.50  2.61  0.84      3.69  2.91  21.23   0.478    0.266
#
#    ft_pct
# 0   0.787
# 1   0.784
# 2   0.706
# 3   0.808
# ...

# %%
df.shape
# Out:
# (1003, 24)

# %%
df.columns
# Out:
# Index(['first', 'last', 'team', 'year', 'games_played', 'min', 'fgm', 'fga',
#        'fg3m', 'fg3a', 'ftm', 'fta', 'oreb', 'dreb', 'reb', 'ast', 'stl',
#        'blk', 'turnover', 'pf', 'pts', 'fg_pct', 'fg3_pct', 'ft_pct'],
#       dtype='object')

# %% [markdown]
# - Qual a quantidade de jogadores que foram all-starts por time?
# - Qual a média de turnover que os jogadores all-starts eleitos tiveram?
# - Qual média de pontos feitos pelos jogadores...?
# - Por ano de quantidade de jogadores all-starts
# - A quantidade de cesta por ano aumentou dos all-stars?
# - A quantidade de jogos jogados por ano aumentou dos all-stars?
# - média de pontos feitos por time?

# %% [markdown]
# ## Analises

# %%
ax = sns.countplot(df.team)
ax.figure.set_size_inches(15,5)
# Out:
# /Users/lauradamaceno/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df[df.team=='MEM'].shape
# Out:
# (9, 24)

# %%
df[df.team=='BOS'].shape
# Out:
# (65, 24)

# %%
mem = df[df.team=='MEM']
bos = df[df.team=='BOS']

# %%
ax = sns.countplot(mem.year)
# Out:
# /Users/lauradamaceno/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
mem[mem.year == 2022]
# Out:
#       first         last team  year  games_played       min   fgm    fga  \
# 982      Ja       Morant  MEM  2022          61.0  31:57:00  9.28  19.90
# 1002  Jaren  Jackson Jr.  MEM  2022          63.0  28:24:00  6.60  13.05
#
#       fg3m  fg3a  ...   reb   ast   stl   blk  turnover    pf    pts  fg_pct  \
# 982   1.51  4.92  ...  5.85  8.08  1.08  0.26      3.38  1.64  26.16   0.466
# 1002  1.59  4.48  ...  6.76  0.95  1.03  3.00      1.70  3.60  18.62   0.506
#
#       fg3_pct  ft_pct
# 982     0.307   0.748
# 1002    0.355   0.788
#
# [2 rows x 24 columns]

# %%
ax = sns.countplot(bos.year)
ax.figure.set_size_inches(15,5)
# Out:
# /Users/lauradamaceno/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
bos[bos.year == 2010]
# Out:
#      first     last team  year  games_played       min   fgm    fga  fg3m  \
# 711  Rajon    Rondo  BOS  2010          68.0  37:05:00  4.68   9.85  0.15
# 713    Ray    Allen  BOS  2010          80.0  36:08:00  6.00  12.23  2.10
# 714   Paul   Pierce  BOS  2010          80.0  34:40:00  6.34  12.76  1.39
# 716  Kevin  Garnett  BOS  2010          71.0  31:14:00  6.11  11.58  0.01
#
#      fg3a  ...   reb    ast   stl   blk  turnover    pf    pts  fg_pct  \
# 711  0.63  ...  4.37  11.18  2.25  0.16      3.44  1.76  10.60   0.475
# 713  4.73  ...  3.43   2.74  0.96  0.20      1.46  1.84  16.51   0.491
# 714  3.71  ...  5.38   3.25  1.00  0.64      2.14  2.89  18.89   0.497
# 716  0.07  ...  8.89   2.41  1.34  0.80      1.62  2.08  14.87   0.528
#
#      fg3_pct  ft_pct
# 711    0.233   0.568
# 713    0.444   0.881
# 714    0.374   0.860
# 716    0.200   0.862
#
# [4 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first         1003 non-null   object
#  1   last          1003 non-null   object
#  2   team          1003 non-null   object
#  3   year          1003 non-null   int64
#  4   games_played  1002 non-null   float64
#  5   min           1002 non-null   object
#  6   fgm           1002 non-null   float64
#  7   fga           1002 non-null   float64
#  8   fg3m          1002 non-null   float64
#  9   fg3a          1002 non-null   float64
#  10  ftm           1002 non-null   float64
#  11  fta           1002 non-null   float64
#  12  oreb          1002 non-null   float64
#  13  dreb          1002 non-null   float64
#  14  reb           1002 non-null   float64
#  15  ast           1002 non-null   float64
#  16  stl           1002 non-null   float64
# ...

# %%
df[df['games_played'].isna()]
# Out:
#      first     last team  year  games_played  min  fgm  fga  fg3m  fg3a  ...  \
# 261  Magic  Johnson  LAL  1991           NaN  NaN  NaN  NaN   NaN   NaN  ...
#
#      reb  ast  stl  blk  turnover  pf  pts  fg_pct  fg3_pct  ft_pct
# 261  NaN  NaN  NaN  NaN       NaN NaN  NaN     NaN      NaN     NaN
#
# [1 rows x 24 columns]

# %%
df_2 = df.dropna(subset='games_played')

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1002 entries, 0 to 1002
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first         1002 non-null   object
#  1   last          1002 non-null   object
#  2   team          1002 non-null   object
#  3   year          1002 non-null   int64
#  4   games_played  1002 non-null   float64
#  5   min           1002 non-null   object
#  6   fgm           1002 non-null   float64
#  7   fga           1002 non-null   float64
#  8   fg3m          1002 non-null   float64
#  9   fg3a          1002 non-null   float64
#  10  ftm           1002 non-null   float64
#  11  fta           1002 non-null   float64
#  12  oreb          1002 non-null   float64
#  13  dreb          1002 non-null   float64
#  14  reb           1002 non-null   float64
#  15  ast           1002 non-null   float64
#  16  stl           1002 non-null   float64
# ...

# %%
df_2.head()
# Out:
#     first     last team  year  games_played       min   fgm    fga  fg3m  \
# 0  Julius   Erving  PHI  1980          82.0  35:02:00  9.68  18.59  0.05
# 1   Eddie  Johnson  ATL  1980          75.0  35:55:00  7.64  15.16  0.08
# 2   Artis  Gilmore  CHI  1980          81.0  34:31:00  6.67   9.93  0.00
# 3  Reggie    Theus  CHI  1980          81.0  34:20:00  6.58  13.38  0.22
# 4   Larry     Bird  BOS  1980          82.0  39:30:00  8.77  18.33  0.24
#
#    fg3a  ...    reb   ast   stl   blk  turnover    pf    pts  fg_pct  fg3_pct  \
# 0  0.22  ...   8.01  4.44  2.62  1.73      3.40  2.84  24.56   0.521    0.220
# 1  0.32  ...   2.39  5.47  1.54  0.11      2.70  2.53  19.08   0.504    0.249
# 2  0.00  ...  10.06  2.15  0.77  2.43      3.31  3.58  17.89   0.672    0.000
# 3  1.09  ...   3.56  5.41  1.73  0.28      3.65  3.14  18.84   0.492    0.203
# 4  0.92  ...  10.91  5.50  2.61  0.84      3.69  2.91  21.23   0.478    0.266
#
#    ft_pct
# 0   0.787
# 1   0.784
# 2   0.706
# 3   0.808
# ...

# %%
df_2.games_played.min()
# Out:
# 19.0

# %%
df_2.games_played = df_2.games_played.astype(int)
# Out:
# /var/folders/x9/677608_s3v59vr4xn87k94d40000gn/T/ipykernel_71987/3378925748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.games_played = df_2.games_played.astype(int)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1002 entries, 0 to 1002
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first         1002 non-null   object
#  1   last          1002 non-null   object
#  2   team          1002 non-null   object
#  3   year          1002 non-null   int64
#  4   games_played  1002 non-null   int64
#  5   min           1002 non-null   object
#  6   fgm           1002 non-null   float64
#  7   fga           1002 non-null   float64
#  8   fg3m          1002 non-null   float64
#  9   fg3a          1002 non-null   float64
#  10  ftm           1002 non-null   float64
#  11  fta           1002 non-null   float64
#  12  oreb          1002 non-null   float64
#  13  dreb          1002 non-null   float64
#  14  reb           1002 non-null   float64
#  15  ast           1002 non-null   float64
#  16  stl           1002 non-null   float64
# ...

# %%
df_2.describe()
# Out:
#               year  games_played          fgm          fga         fg3m  \
# count  1002.000000   1002.000000  1002.000000  1002.000000  1002.000000
# mean   2001.089820     74.638723     7.938263    16.273962     0.930050
# std      12.514364      8.615857     1.754162     3.653592     1.022842
# min    1980.000000     19.000000     2.290000     4.690000     0.000000
# 25%    1990.000000     71.000000     6.740000    13.852500     0.040000
# 50%    2002.000000     78.000000     7.915000    16.405000     0.570000
# 75%    2012.000000     81.000000     9.137500    18.835000     1.550000
# max    2022.000000     82.000000    13.390000    27.820000     5.350000
#
#               fg3a          ftm          fta         oreb         dreb  \
# count  1002.000000  1002.000000  1002.000000  1002.000000  1002.000000
# mean      2.582745     4.758134     6.058124     1.858523     5.358493
# std       2.649796     1.696613     2.133658     1.150622     2.293323
# ...

# %%
df_2[df_2.duplicated(subset='first',keep=False)]
# Out:
#        first     last team  year  games_played       min    fgm    fga  fg3m  \
# 0     Julius   Erving  PHI  1980            82  35:02:00   9.68  18.59  0.05
# 1      Eddie  Johnson  ATL  1980            75  35:55:00   7.64  15.16  0.08
# 2      Artis  Gilmore  CHI  1980            81  34:31:00   6.67   9.93  0.00
# 3     Reggie    Theus  CHI  1980            81  34:20:00   6.58  13.38  0.22
# 4      Larry     Bird  BOS  1980            82  39:30:00   8.77  18.33  0.24
# ..       ...      ...  ...   ...           ...       ...    ...    ...   ...
# 995   LeBron    James  LAL  2022            56  35:42:00  11.09  22.14  2.21
# 996   Jaylen    Brown  BOS  2022            67  35:56:00  10.13  20.64  2.43
# 997   Julius   Randle  NYK  2022            77  35:35:00   8.55  18.60  2.83
# 998     Paul   George  LAC  2022            56  34:39:00   8.20  17.93  2.82
# 999  Anthony  Edwards  MIN  2022            81  36:10:00   8.86  19.47  2.67
#
# ...

# %%
df_2.columns
# Out:
# Index(['first', 'last', 'team', 'year', 'games_played', 'min', 'fgm', 'fga',
#        'fg3m', 'fg3a', 'ftm', 'fta', 'oreb', 'dreb', 'reb', 'ast', 'stl',
#        'blk', 'turnover', 'pf', 'pts', 'fg_pct', 'fg3_pct', 'ft_pct'],
#       dtype='object')

# %% [markdown]
# Teve um jogador que foi mais vezes all-star que o Lebron?

# %%
df_2.groupby(by=['first','last'])['year'].count().to_frame().sort_values(by='year',ascending=False)
# Out:
#                   year
# first   last
# LeBron  James       19
# Kobe    Bryant      15
# Tim     Duncan      15
# Kevin   Garnett     14
# Dirk    Nowitzki    14
# ...                ...
# Mike    Conley       1
# Gerald  Wallace      1
# Michael Redd         1
# Goran   Dragic       1
# A.C.    Green        1
#
# [278 rows x 1 columns]

# %%
df_2[df_2['first']=='LeBron']
# Out:
#       first   last team  year  games_played       min    fgm    fga  fg3m  \
# 550  LeBron  James  CLE  2004            80  42:17:00   9.94  21.05  1.35
# 574  LeBron  James  CLE  2005            79  42:31:00  11.08  23.08  1.61
# 609  LeBron  James  CLE  2006            78  40:54:00   9.90  20.78  1.27
# 622  LeBron  James  CLE  2007            75  40:21:00  10.59  21.89  1.51
# 658  LeBron  James  CLE  2008            81  37:42:00   9.74  19.91  1.63
# 669  LeBron  James  CLE  2009            76  39:01:00  10.11  20.11  1.70
# 705  LeBron  James  MIA  2010            79  38:46:00   9.59  18.80  1.16
# 730  LeBron  James  MIA  2011            62  37:32:00  10.02  18.85  0.87
# 754  LeBron  James  MIA  2012            76  37:51:00  10.07  17.82  1.36
# 766  LeBron  James  MIA  2013            77  37:42:00   9.96  17.57  1.51
# 801  LeBron  James  CLE  2014            69  36:08:00   9.04  18.54  1.74
# 829  LeBron  James  CLE  2015            76  35:38:00   9.70  18.63  1.14
# ...

# %%
sns.countplot(df_2[df_2['first']=='LeBron']['team'])
# Out:
# /Users/lauradamaceno/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='team', ylabel='count'>

# %%
df_2.groupby(by='year')['first'].count().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df_2.groupby(by='year')['first'].count()
# Out:
# year
# 1980    22
# 1981    24
# 1982    24
# 1983    24
# 1984    24
# 1985    23
# 1986    24
# 1987    24
# 1988    24
# 1989    24
# 1990    24
# 1991    24
# 1992    24
# 1993    24
# 1994    24
# 1995    24
# 1996    24
# 1997    24
# 1999    24
# 2000    24
# 2001    23
# 2002    24
# 2003    24
# 2004    24
# 2005    24
# 2006    24
# 2007    24
# 2008    24
# 2009    24
# 2010    24
# 2011    24
# 2012    24
# 2013    24
# 2014    24
# 2015    24
# 2016    24
# 2017    23
# 2018    26
# 2019    24
# 2020    22
# 2021    23
# 2022    24
# Name: first, dtype: int64

# %%
df_2[df_2.year==2020].shape
# Out:
# (22, 24)

# %%
df_2[df_2.year>=2020].shape
# Out:
# (69, 24)

# %%
df_2.groupby(by='year')['fgm'].mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df_2.groupby(by='year')['fg3m'].mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
cesta_3pontos = df_2.groupby(by=['first','last'])['fg3m'].median().to_frame().sort_values(by='fg3m',ascending=False)
cesta_3pontos
# Out:
#                     fg3m
# first   last
# Stephen Curry      4.295
# Fred    VanVleet   3.680
# Donovan Mitchell   3.360
# Trae    Young      3.230
# Klay    Thompson   3.140
# ...                  ...
# Brook   Lopez      0.000
# Brad    Daugherty  0.000
# Dikembe Mutombo    0.000
# Bob     Lanier     0.000
# DeAndre Jordan     0.000
#
# [278 rows x 1 columns]

# %%
cesta_3pontos[cesta_3pontos.fg3m==0].shape
# Out:
# (41, 1)

# %%
df_2.groupby(by='year')['blk'].mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df_2.groupby(by=['first','last'])['blk'].median().to_frame().sort_values(by='blk',ascending=False)
# Out:
#                        blk
# first   last
# Mark    Eaton        3.840
# Hakeem  Olajuwon     3.360
# Dikembe Mutombo      3.290
# David   Robinson     3.265
# Jaren   Jackson Jr.  3.000
# ...                    ...
# Tony    Parker       0.080
# Steve   Nash         0.080
# Michael Redd         0.070
# Norm    Nixon        0.055
# Dana    Barros       0.050
#
# [278 rows x 1 columns]

# %%
df_time_pontos = df_2.groupby(by=['team','year'])['pts'].mean().to_frame().sort_values(by='pts',ascending=False)

df_time_pontos
# Out:
#              pts
# team year
# CHI  1986  37.09
# HOU  2018  36.13
# LAL  2005  35.40
# CHI  1987  34.98
# PHI  2022  33.08
# ...          ...
# ATL  2000   9.99
# DET  2004   9.74
#      2003   9.54
# DAL  2018   7.31
# DET  2002   6.93
#
# [700 rows x 1 columns]

# %%
df_time_pontos.team.nunique()
# Out:
# 37

# %%
df_time_pontos_100 = df_time_pontos[:130].reset_index()

# %%
ax = sns.lineplot(data=df_time_pontos_100, x="year", y="pts", hue="team")
ax.figure.set_size_inches(15,5)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
